# %%
from PIL import Image, ImageFilter
import matplotlib.pyplot as plt

img = Image.open('../img/street-sign.jpg')

# EMBOSS filter
img_filter = img.filter(ImageFilter.EMBOSS)
print("Filter by: EMBOSS")
plt.imshow(img_filter)
plt.show()


# EDGE_ENHANCE filter
img_filter = img.filter(ImageFilter.EDGE_ENHANCE)
print("Filter by: EDGE_ENHANCE")
plt.imshow(img_filter)
plt.show()


# CONTOUR filter
img_filter = img.filter(ImageFilter.CONTOUR)
print("Filter by: CONTOUR")
plt.imshow(img_filter)
plt.show()


# SHARPEN filter
img_filter = img.filter(ImageFilter.SHARPEN)
print("Filter by: SHARPEN")
plt.imshow(img_filter)
plt.show()


# BLUR filter
img_filter = img.filter(ImageFilter.BLUR)
print("Filter by: BLUR")
plt.imshow(img_filter)
plt.show()
# Out:
# Filter by: EMBOSS
# Filter by: EDGE_ENHANCE
# Filter by: CONTOUR
# Filter by: SHARPEN
# Filter by: BLUR
